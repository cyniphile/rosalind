# %%
import pandas as pd
import numpy as np
import math

# %%
a = sorted(np.random.randint(50,size=13))
b = sorted(np.random.randint(50,size=(10)), reverse=False)
a, b = np.meshgrid(a, b)
a + b - 50
# Out:
# array([[-47, -44, -43, -36, -29, -25, -23, -16, -12,  -8,  -6,  -5,   0],
#        [-26, -23, -22, -15,  -8,  -4,  -2,   5,   9,  13,  15,  16,  21],
#        [-23, -20, -19, -12,  -5,  -1,   1,   8,  12,  16,  18,  19,  24],
#        [-14, -11, -10,  -3,   4,   8,  10,  17,  21,  25,  27,  28,  33],
#        [-11,  -8,  -7,   0,   7,  11,  13,  20,  24,  28,  30,  31,  36],
#        [ -8,  -5,  -4,   3,  10,  14,  16,  23,  27,  31,  33,  34,  39],
#        [ -7,  -4,  -3,   4,  11,  15,  17,  24,  28,  32,  34,  35,  40],
#        [ -6,  -3,  -2,   5,  12,  16,  18,  25,  29,  33,  35,  36,  41],
#        [ -5,  -2,  -1,   6,  13,  17,  19,  26,  30,  34,  36,  37,  42],
#        [ -1,   2,   3,  10,  17,  21,  23,  30,  34,  38,  40,  41,  46]])

# %%
# Out:
# Dups M: 0.0 of 9
# Dups A: 0.0 of 10
# Dups S: 0.125 of 8
#    index   0
# 0      0   3
# 1      1  12
# 2      5  45
# 3      8  47
# 4      7  68
# 5      4  76
# 6      2  81
# 7      6  92
# 8      3  99
#    index   0
# 0      6  70
# 1      8  56
# 2      5  48
# 3      1  45
# 4      0   2
# 5      9  -8
# 6      3  -9
# 7      7 -37
# 8      4 -50
# 9      2 -63
# s 79
# lMssRemain 9
# lMssRemain 4.5
# lMssRemain 5
# i 4
# lMssRemain 5
# lMssRemain 2.5
# lMssRemain 2
# i 3
# lMssRemain 2
# lMssRemain 1.0
# lMssRemain 1
# i 3
# lAssRemain 10
# lAssRemain 5.0
# lAssRemain 5
# j 4
# lAssRemain 5
# lAssRemain 2.5
# lAssRemain 2
# j 3
# lAssRemain 2
# lAssRemain 1.0
# lAssRemain 1
# j 3
# lAssRemain 1
# lAssRemain 0.5
# lAssRemain 1
# j 3
# lAssRemain 1
# lAssRemain 0.5
# lAssRemain 1
# j 3
# lAssRemain 1
# lAssRemain 0.5
# lAssRemain 1
# j 3
# lAssRemain 1
# lAssRemain 0.5
# lAssRemain 1
# j 3
# lAssRemain 1
# lAssRemain 0.5
# lAssRemain 1
# j 3
# lAssRemain 1
# lAssRemain 0.5
# ...

# %%
setup('./all2/2.txt', './answer2.txt', minimize_all_deltas, test=False)
# Out:
# Dups M: 0.7954070981210856 of 479
# Dups A: 0.6198347107438017 of 484
# Dups S: 0.7847826086956522 of 460
# 0
# Dups M: 0.0 of 475
# Dups A: 0.0 of 469
# Dups S: 0.0 of 468
# 1
#          83782 function calls (83662 primitive calls) in 1.648 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    1.607    0.804    1.639    0.819 <ipython-input-217-2dea14d89ec8>:1(minimize_all_deltas)
#     67101    0.009    0.000    0.009    0.000 {built-in method builtins.abs}
#       567    0.004    0.000    0.004    0.000 <ipython-input-150-d20945ae57ec>:25(<listcomp>)
#      1144    0.003    0.000    0.006    0.000 base.py:4279(__getitem__)
#         1    0.002    0.002    0.003    0.003 {method 'readlines' of '_io._IOBase' objects}
#        54    0.002    0.000    0.002    0.000 socket.py:438(send)
#         2    0.002    0.001    0.002    0.001 {method '__exit__' of '_io._IOBase' objects}
# ...

# %%
setup('./all2/3.txt', './answer3.txt', minimize_all_deltas, test=False)
# Out:
# Dups M: 0.8996990972918756 of 997
# Dups A: 0.8016032064128257 of 998
# Dups S: 0.9989916407014148 of 99171
# 0
# Dups M: 0.0 of 995
# Dups A: 0.0 of 994
# Dups S: 7.016699745394037e-05 of 99762
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-222-7bb461835150> in <module>
# ----> 1 setup('./all2/3.txt', './answer3.txt', minimize_all_deltas, test=False)
#
# <ipython-input-150-d20945ae57ec> in setup(test_file, answer_output_file, function, test)
#      13             # assert(len(As) == int(K))
#      14             # assert(len(Ss) == int(N))
# ---> 15             answers = function(Ss, Ms, As)
#      16             if not test:
#      17                 a.write("\n".join(answers) + "\n")
#
# <ipython-input-217-2dea14d89ec8> in minimize_all_deltas(Ss, Ms, As)
#      43                         else:
#      44                             j = j - lAssRemain
# ...

# %%
setup('./all2/4.txt', './answer4.txt', minimize_all_deltas, test=False)
# Out:
# Dups M: 0.9998997471623434 of 997478
# Dups A: 0.7995991983967936 of 998
# Dups S: 0.8991935483870968 of 992
# 0
# Dups M: 0.000517682823644387 of 998681
# Dups A: 0.0 of 994
# Dups S: 0.0 of 996
# 1

# %%
setup('./all2/5.txt', './answer5.txt', minimize_all_deltas, test=False)
# Out:
# Dups M: 0.0001 of 10000
# Dups A: 0.0 of 10000
# Dups S: 0.0 of 10000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-224-590c0659499b> in <module>
# ----> 1 setup('./all2/5.txt', './answer5.txt', minimize_all_deltas, test=False)
#
# <ipython-input-150-d20945ae57ec> in setup(test_file, answer_output_file, function, test)
#      13             # assert(len(As) == int(K))
#      14             # assert(len(Ss) == int(N))
# ---> 15             answers = function(Ss, Ms, As)
#      16             if not test:
#      17                 a.write("\n".join(answers) + "\n")
#
# <ipython-input-217-2dea14d89ec8> in minimize_all_deltas(Ss, Ms, As)
#      30                     while lMssRemain >= 1:
#      31                         lMssRemain = lMssRemain >> 1
# ---> 32                         if d < 0:
#      33                             i = i + lMssRemain
# ...
